# %%
import json
import os

db_file = "kassite_names_db.json"

if os.path.exists(db_file):
    with open(db_file, "r", encoding="utf-8") as file:
        db = json.load(file)
    print(f"Database loaded! {len(db)} entries found.")
else:
    db = []
    print("New database initialized.")
# Out:
# Database loaded! 185 entries found.

# %%
kassitische_datenbank = []
wort_1 = {
    "transcription": "mali", 
    "meaning": "human", 
    "word type": "Noun", 
    "liability": "sure"
}

wort_2 = { "transcription": "alzibadar", "meaning": "colour term", "word type": "adjective"} 

wort_3 = { "transcription": "bur", "meaning": "strong", "word type": "adjective"}

kassitische_datenbank.append(wort_1)
kassitische_datenbank.append(wort_2)
kassitische_datenbank.append(wort_3)

print(f"Anzahl der Wörter in der Datenbank: {len(db)}")
print(kassitische_datenbank)

import json
with open("kassite_names_db.json", "w", encoding="utf-8") as file:
    json.dump(kassitische_datenbank, file, indent=4)
print("Saved to file!")
# Out:
# Anzahl der Wörter in der Datenbank: 185
# [{'transcription': 'mali', 'meaning': 'human', 'word type': 'Noun', 'liability': 'sure'}, {'transcription': 'alzibadar', 'meaning': 'colour term', 'word type': 'adjective'}, {'transcription': 'bur', 'meaning': 'strong', 'word type': 'adjective'}]
# Saved to file!

# %%
import pandas as pd
import json
import os


db_file = "kassite_names_db.json"
if os.path.exists(db_file):
    try:
        with open(db_file, "r", encoding="utf-8") as file:
            db = json.load(file)
        print(f"Datenbank geladen: {len(db)} Eintraege gefunden.")
    except json.JSONDecodeError:
        db = []
        print("Datei war leer oder fehlerhaft, starte neue Datenbank.")
else:
    db = []
    print("Neue Datenbank initialisiert.")


excel_file = None
for f in os.listdir():
    if f.startswith("Kassitische") and f.endswith(".xlsx") and not f.startswith("~$"):
        excel_file = f
        break


if excel_file:
    print(f"Datei gefunden: {excel_file}")
    df = pd.read_excel(excel_file)
    df.columns = df.columns.str.strip()
    
    vorhandene_namen = {eintrag.get("transcription") for eintrag in db}
    neue_zaehler = 0  
    
    for _, row in df.iterrows():
        name = str(row.get("Name", "")).strip()
        
        if name and name not in vorhandene_namen:
            neu_eintrag = { 
                "transcription": name, 
                "morphemes": str(row.get("Morpheme", "")).strip() if pd.notna(row.get("Morpheme")) else "",
                "meaning": str(row.get("Bedeutung", "")).strip() if pd.notna(row.get("Bedeutung")) else "",
                "position": str(row.get("Position", "")).strip() if pd.notna(row.get("Position")) else "",
                "function": str(row.get("Funktion", "")).strip() if pd.notna(row.get("Funktion")) else ""
            }
            db.append(neu_eintrag)
            vorhandene_namen.add(name)
            neue_zaehler += 1

    print(f"Import abgeschlossen: {neue_zaehler} Namen hinzugefuegt.")
    print(f"Neuer Gesamtstand: {len(db)}")
else:
    print("Keine Excel-Datei gefunden.")


with open(db_file, "w", encoding="utf-8") as f:
    json.dump(db, f, indent=4, ensure_ascii=False)
print(f"Daten erfolgreich in {db_file} gespeichert.")


def push_to_github():
    os.system("git add .")
    commit_msg = "Update database structure and entries"
    if os.system(f'git commit -m "{commit_msg}"') == 0:
        os.system("git push origin main")
        print("GitHub Upload abgeschlossen.")
    else:
        print("Keine neuen Änderungen für GitHub vorhanden.")

push_to_github()
# Out:
# Datenbank geladen: 3 Eintraege gefunden.
# Datei gefunden: Kassitische_Personen_Namen.xlsx
# Import abgeschlossen: 182 Namen hinzugefuegt.
# Neuer Gesamtstand: 185
# Daten erfolgreich in kassite_names_db.json gespeichert.
# [main 3e96c93] Update database structure and entries
#  1 file changed, 53 insertions(+), 10 deletions(-)
# GitHub Upload abgeschlossen.
# To https://github.com/hsschier-lang/kassite-database.git
#    f3dd3c8..3e96c93  main -> main

# %%
import json
import os

with open("kassite_names_db.json", "w", encoding="utf-8") as f:
    
    json.dump(db, f, indent=4, ensure_ascii=False)

print("Die Datei 'kassite_names_db.json' wurde lokal aktualisiert!")

def push_to_github():
    print(" Starte GitHub-Upload...")
    os.system("git add .")
    
    if os.system('git commit -m "Integrated Excel data into JSON database"') == 0:
        os.system("git push origin main")
        print ("Alles ist jetzt online auf GitHub!")
    else:
        print("Keine neuen Änderungen zum Hochladen gefunden.")

push_to_github()
# Out:
# Die Datei 'kassite_names_db.json' wurde lokal aktualisiert!
#  Starte GitHub-Upload...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Keine neuen Änderungen zum Hochladen gefunden.

# %%
import os

def notebook_und_db_hochladen():
    print("Starte Upload fuer Notebook und JSON...")
    
    
    os.system("git add .")
    
    
    commit_msg = "Notebook und Datenbank aktualisiert"
    result = os.system(f'git commit -m "{commit_msg}"')
    
    
    if result == 0:
        os.system("git push origin main")
        print("Erfolg: Notebook und Datenbank sind jetzt auf GitHub aktuell!")
    else:
        print("Info: Keine neuen Aenderungen im Notebook gefunden. Hast du gespeichert?")


notebook_und_db_hochladen()
# Out:
# Starte Upload fuer Notebook und JSON...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Info: Keine neuen Aenderungen im Notebook gefunden. Hast du gespeichert?

# %%
import json
import os

db_file = "kassite_names_db.json"

if os.path.exists(db_file):
    with open(db_file, "r", encoding="utf-8") as file:
        kassite_db = json.load(file)
    print(f"Database loaded! {len(kassite_db)} entries found.")
else:
    kassite_db = []
    print("New database initialized.")
# Out:
# Database loaded! 185 entries found.

# %%
# !pip install lingpy
# Out:
# Requirement already satisfied: lingpy in ./.venv/lib/python3.14/site-packages (2.6.13)
# Requirement already satisfied: numpy in ./.venv/lib/python3.14/site-packages (from lingpy) (2.4.0)
# Requirement already satisfied: appdirs in ./.venv/lib/python3.14/site-packages (from lingpy) (1.4.4)
# Requirement already satisfied: networkx>=2.3 in ./.venv/lib/python3.14/site-packages (from lingpy) (3.6.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.14/site-packages (from lingpy) (4.67.1)
# Requirement already satisfied: csvw>=1.5.6 in ./.venv/lib/python3.14/site-packages (from lingpy) (3.7.0)
# Requirement already satisfied: clldutils>=2.8.0 in ./.venv/lib/python3.14/site-packages (from lingpy) (3.24.2)
# Requirement already satisfied: pycldf>=1.7.0 in ./.venv/lib/python3.14/site-packages (from lingpy) (1.43.0)
# Requirement already satisfied: lxml in ./.venv/lib/python3.14/site-packages (from lingpy) (6.0.2)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (2.9.0.post0)
# Requirement already satisfied: tabulate>=0.7.7 in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (0.9.0)
# Requirement already satisfied: colorlog in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (6.10.1)
# Requirement already satisfied: attrs>=18.1.0 in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (25.4.0)
# Requirement already satisfied: bibtexparser>=2.0.0b4 in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (2.0.0b8)
# Requirement already satisfied: pylatexenc in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (2.10)
# Requirement already satisfied: markdown in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (3.10)
# Requirement already satisfied: markupsafe in ./.venv/lib/python3.14/site-packages (from clldutils>=2.8.0->lingpy) (3.0.3)
# Requirement already satisfied: isodate in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (0.7.2)
# Requirement already satisfied: rfc3986<2 in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (4.2.0)
# Requirement already satisfied: babel in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (2.17.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (2.32.5)
# Requirement already satisfied: language-tags in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (1.2.0)
# Requirement already satisfied: rdflib in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (7.5.0)
# Requirement already satisfied: termcolor in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (3.3.0)
# Requirement already satisfied: jsonschema in ./.venv/lib/python3.14/site-packages (from csvw>=1.5.6->lingpy) (4.25.1)
# Requirement already satisfied: simplepybtex in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (0.1.0)
# Requirement already satisfied: newick in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (1.10.0)
# Requirement already satisfied: commonnexus>=1.2.0 in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (1.9.2)
# Requirement already satisfied: python-frontmatter in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (1.1.0)
# Requirement already satisfied: PyYAML in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (6.0.3)
# Requirement already satisfied: jmespath in ./.venv/lib/python3.14/site-packages (from pycldf>=1.7.0->lingpy) (1.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.14/site-packages (from jsonschema->csvw>=1.5.6->lingpy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.14/site-packages (from jsonschema->csvw>=1.5.6->lingpy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.14/site-packages (from jsonschema->csvw>=1.5.6->lingpy) (0.30.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil->clldutils>=2.8.0->lingpy) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in ./.venv/lib/python3.14/site-packages (from rdflib->csvw>=1.5.6->lingpy) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests->csvw>=1.5.6->lingpy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests->csvw>=1.5.6->lingpy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests->csvw>=1.5.6->lingpy) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests->csvw>=1.5.6->lingpy) (2025.11.12)

# %%
import json 
from lingpy import *

db_file = "kassite_names_db.json"

if os.path.exists(db_file):
    with open(db_file, "r", encoding="utf-8") as f:
        db = json.load(f)
    print(f"Datenbank geladen: {len(db)} Eintraege.")
lp_data = {}

lp_data[0] = ["doculect","concept","transcription", "morphemes"]

for i, eintrag in enumerate(db):
    lp_data[i+1] = [ 
"Kassitisch",                  
        eintrag.get("meaning", "NA"),   
        eintrag.get("transcription", ""),
        eintrag.get("morphemes", "")     
    ]
columns = ["transcription"], "meaning", "morphemes"
wl = Wordlist(lp_data, row='concept', col= 'doculect')

print(f"LingPy hat {wl.height} Einträge geladen.")

alle_morpheme = []
for entry in db:
    m = entry.get("morphemes","")
    if m:
        teile = [t.strip() for t in m.split("-")]
        alle_morpheme.extend(teile)
        
morphem_set = sorted(list(set(alle_morpheme)))  
print(f"Gefundene einzigartige Morpheme: {len(morphem_set)}")      
print("-" * 30)   
print("Vorschau der ersten 10 Morpheme:")
print(morphem_set[:10])
# Out:
# Datenbank geladen: 185 Eintraege.
# LingPy hat 5 Einträge geladen.
# Gefundene einzigartige Morpheme: 158
# ------------------------------
# Vorschau der ersten 10 Morpheme:
# ['Al', 'Bug', 'Bun', 'Bunn', 'Bunna', 'Bunā', 'Bur', 'Dimaḫdi', 'Gab', 'Gisuk']

# %%
from lingpy.sequence.sound_classes import tokens2class

wl.add_entries('tokens', 'transcription', lambda x: x.replace('-', ' ').split())

print("Linguistische Analyse der ersten 5 Namen:")
print(f"{'Name':<15} | {'Tokens':<20} | {'CV-Muster'}")
print("-" * 55)

for idx in wl.indices[:5]:
    tokens = wl[idx, 'tokens']
    
    if tokens:
        try:
            cv_pattern = tokens2class(tokens, 'cv')
        except:
            cv_pattern = "Fehler"
    else:
        cv_pattern = "Keine Tokens"
        
    name = wl[idx, 'transcription']
    print(f"{name:<15} | {str(tokens):<20} | {cv_pattern}")
